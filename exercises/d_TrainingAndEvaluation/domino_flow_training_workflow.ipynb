# %% [markdown]
# # ADE Detection — Domino Flow: Parallel Model Training

# %% [markdown]
# This notebook launches the Domino Flow defined in `workflow.py`. The flow orchestrates **parallel training** of three classifiers (XGBoost, AdaBoost, GaussianNB) followed by an automated comparison step that selects the best model by ROC-AUC.

# %%
import os
from domino import Domino
from exercises.d_TrainingAndEvaluation.workflow import ade_detection_workflow

# %% [markdown]
# ## Launch the Flow

# %%
# The workflow runs: AdaBoost + GaussianNB + XGBoost in parallel,
# then compares results and writes the best model name to /workflow/outputs/consolidated

result = ade_detection_workflow()
print('Flow completed. Best model result:', result)

# %% [markdown]
# ## Next Steps
#
# 1. Navigate to **Experiments** in Domino to compare the three model runs side-by-side
# 2. Review the artifacts (calibration plots, learning curves, performance dashboards)
# 3. Register the best model in the **Model Registry**
# 4. Proceed to Exercise 5 to deploy the model as a REST API
